# %% [markdown]
# # 1. Getting VizDoom Up and Running

# %%
# !pip install vizdoom
# Out:
# Requirement already satisfied: vizdoom in c:\users\yeyian pc\anaconda3\lib\site-packages (1.1.13)
# Requirement already satisfied: numpy in c:\users\yeyian pc\anaconda3\lib\site-packages (from vizdoom) (1.21.5)

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config(r'C:\Users\Yeyian PC\Downloads\ViZDoom-master\ViZDoom-master\scenarios\basic.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([50.])

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\users\yeyian pc\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from gym) (1.21.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from gym) (2.0.0)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\yeyian pc\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\yeyian pc\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2

# %%
print (game)
# Out:
# <vizdoom.vizdoom.DoomGame object at 0x000001C197AC0830>

# %%
game.get_state().screen_buffer.shape
# Out:
# (3, 240, 320)

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config(r'C:\Users\Yeyian PC\Downloads\ViZDoom-master\ViZDoom-master\scenarios\basic.cfg')
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %% [markdown]
# # 3. View Game State

# %%
env.reset()
# Out:
# array([[[55],
#         [50],
#         [59],
#         ...,
#         [57],
#         [57],
#         [66]],
#
#        [[68],
#         [65],
#         [65],
#         ...,
#         [56],
#         [67],
#         [72]],
#
#        [[49],
#         [79],
#         [66],
#         ...,
#         [79],
#         [51],
#         [29]],
#
#        ...,
#
#        [[75],
#         [63],
#         [62],
#         ...,
#         [44],
#         [71],
#         [60]],
#
#        [[15],
#         [48],
#         [47],
#         ...,
#         [49],
#         [69],
#         [47]],
#
#        [[22],
#         [14],
#         [26],
#         ...,
#         [57],
#         [37],
#         [39]]], dtype=uint8)

# %%
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in c:\users\yeyian pc\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3) (3.5.1)
# Requirement already satisfied: cloudpickle in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3) (2.0.0)
# Requirement already satisfied: numpy in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3) (1.21.5)
# Requirement already satisfied: pandas in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3) (1.4.2)
# Requirement already satisfied: gym==0.21 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3) (0.21.0)
# Requirement already satisfied: torch>=1.11 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3) (1.12.0)
# Requirement already satisfied: typing-extensions in c:\users\yeyian pc\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3) (4.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (9.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\yeyian pc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2021.3)

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %% [markdown]
# # 3. View State

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\yeyian pc\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\yeyian pc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
# !pip install opencv-python
import cv2
# Out:
# Requirement already satisfied: opencv-python in c:\users\yeyian pc\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\yeyian pc\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %% [markdown]
# # 4. Setup Callback

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\yeyian pc\anaconda3\lib\site-packages (1.12.0)
# Requirement already satisfied: typing-extensions in c:\users\yeyian pc\anaconda3\lib\site-packages (from torch) (4.1.1)

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\yeyian pc\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: matplotlib in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: cloudpickle in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pandas in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: gym==0.21 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: torch>=1.11 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.12.0)
# Requirement already satisfied: numpy in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Requirement already satisfied: opencv-python in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: pillow in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.9.1)
# Requirement already satisfied: protobuf~=3.19.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: psutil in c:\users\yeyian pc\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: importlib-resources in c:\users\yeyian pc\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: tqdm in c:\users\yeyian pc\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: click in c:\users\yeyian pc\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\yeyian pc\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\yeyian pc\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\yeyian pc\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->ale-py==0.7.4->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (61.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: absl-py>=0.4 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.42.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\yeyian pc\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: typing-extensions in c:\users\yeyian pc\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.1.1)
# Requirement already satisfied: colorama in c:\users\yeyian pc\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yeyian pc\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './logs/log_basic'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5. Train Model

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0002, n_steps=1024)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in c:\users\yeyian pc\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (1.33.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (1.21.5)
# Requirement already satisfied: absl-py>=0.4 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (61.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (1.42.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (2.0.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (3.19.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (4.7.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\yeyian pc\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\yeyian pc\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.0)

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_basic\PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.8     |
# |    ep_rew_mean     | -78.2    |
# | time/              |          |
# |    fps             | 149      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.8        |
# |    ep_rew_mean          | -95         |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 2           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.007091307 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -7.87e-05   |
# |    learning_rate        | 0.0002      |
# |    loss                 | 906         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00897     |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.3        |
# |    ep_rew_mean          | -87.9       |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 3           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.008691328 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.066       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0048      |
# |    value_loss           | 3.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.2        |
# |    ep_rew_mean          | -63.1       |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 4           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.021213323 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 850         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 3.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | -24.3       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 5           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.014145365 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.61e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00453     |
# |    value_loss           | 3.5e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.5       |
# |    ep_rew_mean          | -16.3      |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 6          |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.07946214 |
# |    clip_fraction        | 0.444      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.986     |
# |    explained_variance   | 0.606      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.67e+03   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.0215     |
# |    value_loss           | 2.62e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | -39.2       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 7           |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.010238169 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.0109      |
# |    value_loss           | 2.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | -42.9       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 8           |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011354381 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.46e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 2.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.3        |
# |    ep_rew_mean          | -32.3       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 9           |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.010420851 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0195      |
# |    value_loss           | 2.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | -26.2       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 10          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019758675 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.886      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.46e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00713     |
# |    value_loss           | 2.91e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | -23.8       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 11          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.017832011 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 797         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0228      |
# |    value_loss           | 2.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.2        |
# |    ep_rew_mean          | -1.75       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 12          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.034766663 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 947         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.0094      |
# |    value_loss           | 2.78e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.4       |
# |    ep_rew_mean          | -1.3       |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 13         |
# |    time_elapsed         | 368        |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.01530546 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.734     |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 743        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.00605    |
# |    value_loss           | 1.95e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.5         |
# |    ep_rew_mean          | -8.64        |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 14           |
# |    time_elapsed         | 401          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0084985215 |
# |    clip_fraction        | 0.3          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 0.0189       |
# |    value_loss           | 2.44e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | -42.1       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 15          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.018022416 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 636         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00739     |
# |    value_loss           | 1.31e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27         |
# |    ep_rew_mean          | -65        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 16         |
# |    time_elapsed         | 467        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.04426419 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.743     |
# |    explained_variance   | 0.693      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 828        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0186     |
# |    value_loss           | 2.31e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | -31.6       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 17          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.052426077 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00878     |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.6       |
# |    ep_rew_mean          | -29.6      |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 18         |
# |    time_elapsed         | 532        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00903239 |
# |    clip_fraction        | 0.0853     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.416     |
# |    explained_variance   | 0.397      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 2.87e+03   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00522    |
# |    value_loss           | 6.57e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | -29.1       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 19          |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.013705473 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.01e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00408     |
# |    value_loss           | 4.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | -37.4       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 20          |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007802499 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.282      |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 2.13e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0057      |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | -39.7       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 21          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.020748012 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00496     |
# |    value_loss           | 2.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.7        |
# |    ep_rew_mean          | -43.2       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 22          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.041436158 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 584         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00861     |
# |    value_loss           | 2.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | -30         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 23          |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.033953633 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.014       |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.4        |
# |    ep_rew_mean          | -44.9       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 24          |
# |    time_elapsed         | 730         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025139328 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.114      |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00238     |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.6        |
# |    ep_rew_mean          | -22.9       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 25          |
# |    time_elapsed         | 763         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.014035181 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.059      |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 728         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00855     |
# |    value_loss           | 1.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | -22         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 26          |
# |    time_elapsed         | 798         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.047402747 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0811     |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 2.4e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.7         |
# |    ep_rew_mean          | 4.95         |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 27           |
# |    time_elapsed         | 833          |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0025906877 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0236      |
# |    explained_variance   | 0.688        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 685          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 1.7e+03      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21         |
# |    ep_rew_mean          | -6.93      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 28         |
# |    time_elapsed         | 868        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02334292 |
# |    clip_fraction        | 0.0479     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0761    |
# |    explained_variance   | 0.754      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.39e+03   |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.00791    |
# |    value_loss           | 2.26e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.3        |
# |    ep_rew_mean          | -30.6       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 29          |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.008310065 |
# |    clip_fraction        | 0.0243      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0297     |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 862         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 2.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.7        |
# |    ep_rew_mean          | -22.3       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 30          |
# |    time_elapsed         | 935         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012794461 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0478     |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 854         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00508     |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.1        |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 31          |
# |    time_elapsed         | 968         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.017595086 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0431     |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 876         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00332     |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.9       |
# |    ep_rew_mean          | -18.2      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 32         |
# |    time_elapsed         | 1000       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.07490034 |
# |    clip_fraction        | 0.0633     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.126     |
# |    explained_variance   | 0.7        |
# |    learning_rate        | 0.0002     |
# |    loss                 | 596        |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0127     |
# |    value_loss           | 1.37e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26         |
# |    ep_rew_mean          | -45.7      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 33         |
# |    time_elapsed         | 1033       |
# |    total_timesteps      | 33792      |
# | train/                  |            |
# |    approx_kl            | 0.82279664 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.215     |
# |    explained_variance   | 0.618      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 329        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.043      |
# |    value_loss           | 1.09e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.7        |
# |    ep_rew_mean          | -67.4       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 34          |
# |    time_elapsed         | 1066        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.060376413 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0877     |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 767         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0134      |
# |    value_loss           | 1.75e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.9       |
# |    ep_rew_mean          | -61.3      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 35         |
# |    time_elapsed         | 1099       |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.16566342 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.185     |
# |    explained_variance   | 0.506      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 563        |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0298    |
# |    value_loss           | 1.44e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | -34         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 36          |
# |    time_elapsed         | 1133        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.017543796 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0199     |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 560         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0159      |
# |    value_loss           | 1.62e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -16         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 37          |
# |    time_elapsed         | 1166        |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.017945189 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0869     |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 870         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 1.69e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.4        |
# |    ep_rew_mean          | -3.93       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 38          |
# |    time_elapsed         | 1199        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.027009312 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 878         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | 12.5        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 39          |
# |    time_elapsed         | 1233        |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.008934276 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.147      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 682         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 40          |
# |    time_elapsed         | 1267        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.023402113 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 9.93e-05    |
# |    value_loss           | 1.31e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.4       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 41         |
# |    time_elapsed         | 1301       |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.09245952 |
# |    clip_fraction        | 0.0581     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0231    |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.48e+03   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00903    |
# |    value_loss           | 2.67e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.5         |
# |    ep_rew_mean          | -67.7        |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 42           |
# |    time_elapsed         | 1334         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0031862017 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0446      |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 1.09e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000612     |
# |    value_loss           | 1.78e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.7       |
# |    ep_rew_mean          | -36.6      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 43         |
# |    time_elapsed         | 1368       |
# |    total_timesteps      | 44032      |
# | train/                  |            |
# |    approx_kl            | 0.20104165 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.159     |
# |    explained_variance   | 0.542      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 635        |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0372    |
# |    value_loss           | 1.24e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.6       |
# |    ep_rew_mean          | -1.01      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 44         |
# |    time_elapsed         | 1402       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.28035367 |
# |    clip_fraction        | 0.0721     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.031     |
# |    explained_variance   | 0.689      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 701        |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00387   |
# |    value_loss           | 1.71e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 45          |
# |    time_elapsed         | 1436        |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.002415076 |
# |    clip_fraction        | 0.00957     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00864    |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 841         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0051      |
# |    value_loss           | 2.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.5        |
# |    ep_rew_mean          | -9.69       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 46          |
# |    time_elapsed         | 1471        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.018491345 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0321     |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 759         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 2.08e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.7         |
# |    ep_rew_mean          | -26.9        |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 47           |
# |    time_elapsed         | 1506         |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0012861125 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0156      |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 957          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.000514     |
# |    value_loss           | 1.85e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.4        |
# |    ep_rew_mean          | -57.7       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 48          |
# |    time_elapsed         | 1540        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009451999 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00996    |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00785     |
# |    value_loss           | 2.29e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.2         |
# |    ep_rew_mean          | -73.7        |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 49           |
# |    time_elapsed         | 1575         |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0017666877 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0123      |
# |    explained_variance   | 0.583        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 726          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.000373     |
# |    value_loss           | 1.78e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.7         |
# |    ep_rew_mean          | -71.6        |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 50           |
# |    time_elapsed         | 1609         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0023198023 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0498      |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 888          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000935    |
# |    value_loss           | 2.06e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.6        |
# |    ep_rew_mean          | -16.4       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 51          |
# |    time_elapsed         | 1643        |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.037603617 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0523     |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.6        |
# |    ep_rew_mean          | 17.3        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 52          |
# |    time_elapsed         | 1677        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.035971016 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0538     |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 980         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00965     |
# |    value_loss           | 1.94e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.6         |
# |    ep_rew_mean          | 6.01         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 53           |
# |    time_elapsed         | 1710         |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0035345976 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0433      |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 629          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00489      |
# |    value_loss           | 1.75e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | -14.4       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 54          |
# |    time_elapsed         | 1744        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012663901 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0469     |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.000758    |
# |    value_loss           | 2.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.2        |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 55          |
# |    time_elapsed         | 1779        |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.009834932 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0343     |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 736         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00229     |
# |    value_loss           | 1.45e+03    |
# -----------------------------------------
# ------------------------------------------
# ...
# |    learning_rate        | 0.0002     |
# |    loss                 | 1.64e+03   |
# |    n_updates            | 790        |
# |    policy_gradient_loss | 0.00317    |
# |    value_loss           | 2.73e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 81          |
# |    time_elapsed         | 2656        |
# |    total_timesteps      | 82944       |
# | train/                  |             |
# |    approx_kl            | 0.028355815 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 1.98e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.2         |
# |    ep_rew_mean          | 21.2         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 82           |
# |    time_elapsed         | 2689         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0089916065 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.275       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0002       |
# |    loss                 | 877          |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 1.96e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 83          |
# |    time_elapsed         | 2723        |
# |    total_timesteps      | 84992       |
# | train/                  |             |
# |    approx_kl            | 0.016075328 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.242      |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 1.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | 27.8        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 84          |
# |    time_elapsed         | 2757        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019399853 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.09e+03    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.000112    |
# |    value_loss           | 2.25e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.4        |
# |    ep_rew_mean          | 36.1        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 85          |
# |    time_elapsed         | 2790        |
# |    total_timesteps      | 87040       |
# | train/                  |             |
# |    approx_kl            | 0.017211882 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.236      |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 760         |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.000198   |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 47          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 86          |
# |    time_elapsed         | 2824        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.018390652 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.263      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 1.01e+03    |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.57      |
# |    ep_rew_mean          | 67.1      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 87        |
# |    time_elapsed         | 2859      |
# |    total_timesteps      | 89088     |
# | train/                  |           |
# |    approx_kl            | 0.0231397 |
# |    clip_fraction        | 0.116     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.248    |
# |    explained_variance   | 0.868     |
# |    learning_rate        | 0.0002    |
# |    loss                 | 739       |
# |    n_updates            | 860       |
# |    policy_gradient_loss | -0.00261  |
# |    value_loss           | 1.37e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.22       |
# |    ep_rew_mean          | 81.6       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 88         |
# |    time_elapsed         | 2893       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.04153724 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.296     |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 767        |
# |    n_updates            | 870        |
# |    policy_gradient_loss | 0.00775    |
# |    value_loss           | 1.6e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.67        |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 89          |
# |    time_elapsed         | 2927        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.038587414 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.0981      |
# |    learning_rate        | 0.0002      |
# |    loss                 | 242         |
# |    n_updates            | 880         |
# |    policy_gradient_loss | 0.0154      |
# |    value_loss           | 550         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.59       |
# |    ep_rew_mean          | 84.1       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 90         |
# |    time_elapsed         | 2961       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.04675238 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.451     |
# |    explained_variance   | 0.507      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 87.2       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | 0.00885    |
# |    value_loss           | 274        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.27        |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 91          |
# |    time_elapsed         | 2995        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.042033844 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 60.3        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 140         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.95       |
# |    ep_rew_mean          | 86.9       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 92         |
# |    time_elapsed         | 3029       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03184446 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.225     |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 6.67       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | 0.00272    |
# |    value_loss           | 39         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.39       |
# |    ep_rew_mean          | 84.9       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 93         |
# |    time_elapsed         | 3065       |
# |    total_timesteps      | 95232      |
# | train/                  |            |
# |    approx_kl            | 0.04184147 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.199     |
# |    explained_variance   | 0.628      |
# |    learning_rate        | 0.0002     |
# |    loss                 | 31.6       |
# |    n_updates            | 920        |
# |    policy_gradient_loss | 0.0116     |
# |    value_loss           | 76.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.22        |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 94          |
# |    time_elapsed         | 3101        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.045162845 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0002      |
# |    loss                 | 17          |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.000236    |
# |    value_loss           | 50.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.12        |
# |    ep_rew_mean          | 86.2        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 95          |
# |    time_elapsed         | 3137        |
# |    total_timesteps      | 97280       |
# | train/                  |             |
# |    approx_kl            | 0.018804828 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 7.06        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | 0.00439     |
# |    value_loss           | 48          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.97        |
# |    ep_rew_mean          | 86.9        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 96          |
# |    time_elapsed         | 3174        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004821343 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0951     |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 4.72        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.00581     |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.71        |
# |    ep_rew_mean          | 88          |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 97          |
# |    time_elapsed         | 3210        |
# |    total_timesteps      | 99328       |
# | train/                  |             |
# |    approx_kl            | 0.027251408 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0002      |
# |    loss                 | 12.4        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.0168      |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.91       |
# |    ep_rew_mean          | 87.2       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 98         |
# |    time_elapsed         | 3247       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00744663 |
# |    clip_fraction        | 0.0492     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.094     |
# |    explained_variance   | 0.63       |
# |    learning_rate        | 0.0002     |
# |    loss                 | 21.2       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.00148    |
# |    value_loss           | 46.3       |
# ----------------------------------------

# %% [markdown]
# # 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('./train/train_basic/best_model_100000')

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)
# Out:
# C:\Users\Yeyian PC\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
mean_reward
obs = env.reset()

# %%
model.predict(obs)
# Out:
# (2, None)

# %%
for episode in range(100): 
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        # time.sleep(0.20)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
# Out:
# Total Reward for episode 95.0 is 0
# Total Reward for episode 99.0 is 1
# Total Reward for episode 99.0 is 2
# Total Reward for episode 99.0 is 3
# Total Reward for episode 99.0 is 4
# Total Reward for episode 99.0 is 5
# Total Reward for episode 99.0 is 6
# Total Reward for episode 99.0 is 7
# Total Reward for episode 99.0 is 8
# Total Reward for episode 99.0 is 9
# Total Reward for episode 99.0 is 10
# Total Reward for episode 99.0 is 11
# Total Reward for episode 99.0 is 12
# Total Reward for episode 99.0 is 13
# Total Reward for episode 99.0 is 14
# Total Reward for episode 99.0 is 15
# Total Reward for episode 99.0 is 16
# Total Reward for episode 99.0 is 17
# Total Reward for episode 99.0 is 18
# Total Reward for episode 99.0 is 19
# Total Reward for episode 99.0 is 20
# Total Reward for episode 99.0 is 21
# Total Reward for episode 99.0 is 22
# Total Reward for episode 99.0 is 23
# Total Reward for episode 99.0 is 24
# Total Reward for episode 99.0 is 25
# Total Reward for episode 99.0 is 26
# Total Reward for episode 99.0 is 27
# Total Reward for episode 99.0 is 28
# Total Reward for episode 99.0 is 29
# Total Reward for episode 99.0 is 30
# Total Reward for episode 99.0 is 31
# Total Reward for episode 99.0 is 32
# Total Reward for episode 99.0 is 33
# Total Reward for episode 99.0 is 34
# Total Reward for episode 99.0 is 35
# Total Reward for episode 99.0 is 36
# Total Reward for episode 99.0 is 37
# Total Reward for episode 99.0 is 38
# Total Reward for episode 99.0 is 39
# Total Reward for episode 99.0 is 40
# Total Reward for episode 99.0 is 41
# Total Reward for episode 99.0 is 42
# Total Reward for episode 99.0 is 43
# Total Reward for episode 99.0 is 44
# Total Reward for episode 99.0 is 45
# Total Reward for episode 99.0 is 46
# Total Reward for episode 99.0 is 47
# Total Reward for episode 99.0 is 48
# Total Reward for episode 99.0 is 49
# Total Reward for episode 99.0 is 50
# Total Reward for episode 99.0 is 51
# Total Reward for episode 99.0 is 52
# Total Reward for episode 99.0 is 53
# Total Reward for episode 99.0 is 54
# Total Reward for episode 99.0 is 55
# Total Reward for episode 99.0 is 56
# Total Reward for episode 99.0 is 57
# Total Reward for episode 99.0 is 58
# Total Reward for episode 99.0 is 59
# Total Reward for episode 99.0 is 60
# Total Reward for episode 99.0 is 61
# Total Reward for episode 99.0 is 62
# Total Reward for episode 99.0 is 63
# Total Reward for episode 99.0 is 64
# Total Reward for episode 99.0 is 65
# Total Reward for episode 99.0 is 66
# Total Reward for episode 99.0 is 67
# Total Reward for episode 99.0 is 68
# Total Reward for episode 99.0 is 69
# Total Reward for episode 99.0 is 70
# Total Reward for episode 99.0 is 71
# Total Reward for episode 99.0 is 72
# Total Reward for episode 99.0 is 73
# Total Reward for episode 99.0 is 74
# Total Reward for episode 99.0 is 75
# Total Reward for episode 99.0 is 76
# Total Reward for episode 99.0 is 77
# Total Reward for episode 99.0 is 78
# Total Reward for episode 99.0 is 79
# Total Reward for episode 99.0 is 80
# Total Reward for episode 99.0 is 81
# Total Reward for episode 99.0 is 82
# Total Reward for episode 99.0 is 83
# Total Reward for episode 99.0 is 84
# Total Reward for episode 99.0 is 85
# Total Reward for episode 99.0 is 86
# Total Reward for episode 99.0 is 87
# Total Reward for episode 99.0 is 88
# Total Reward for episode 99.0 is 89
# Total Reward for episode 99.0 is 90
# Total Reward for episode 99.0 is 91
# Total Reward for episode 99.0 is 92
# Total Reward for episode 99.0 is 93
# Total Reward for episode 99.0 is 94
# Total Reward for episode 99.0 is 95
# Total Reward for episode 99.0 is 96
# Total Reward for episode 99.0 is 97
# Total Reward for episode 99.0 is 98
# Total Reward for episode 99.0 is 99
